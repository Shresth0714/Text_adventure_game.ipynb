# %%
"""
Zombie's at Hult SF campus - Zombie Hult
Created By: Shresth Sethi
Student ID: 4845215
Submission Date: 10/18/2019
"""
"""
DocString:

    A: Instructions
    The is based on pure imagination where zombies have captured Hult building.
    Player is a zombie hunter. Player need to cross three stages to survive Hult building and win this game.
    Assumtion everone inside the building is a zombie, except Dean Chris.
    Stage 1: First floor - You need to make critical choice/ based on your instinct.
    Stage 2: Second floor - You need to guess the correct code.
    Stage 3: Third floor - Player need to solve two puzzle to reeach helicopter and win.
                            Second puzzle appears only after you ans the first is correct.
    B: Known bugs and errors
    - These chances are just for the options in fail statement not overall game.
    - Name input can take multiple variable, special characters, alphabets, numerics.
    - Still not 100% sure, tried removing max bugs/errors in my current capacity.
"""

import time as t
import sys
def type(text, delay):        #to display letters one after the other with time lapse
    for beep in text:
        print(beep, end = "")
        sys.stdout.flush()
        t.sleep(delay)
        
def haunted_house():    #start of game
        type('\033[1m' + '\033[91m' + "\033[4m" + "ZOMBIE HULT" + '\033[0m' + "!!!\n\n", 0.05) 
        type("\U0001F9DF"*20 + "\n\n" + '\033[36m' +"*"*45 + "\n" + "*"*45 + "\033[0m",0.03)
        type("\nFight for survival in a business school overrun by zombies! Can you stay alive long enough to get Hultians to a place of safety? If Yes...",0.03)        
        type('\033[36m' +"\n"+ "*"*45 + "\n" + "*"*45 + '\033[0m\n\n',0.03)
        name = input(prompt= "\033[1m\033[91mEnter your name to begin the game: \033[0m\033[0m")        
        t.sleep(0.05)
        type("\nYou are entring Hult building {} \U0001F603 \n \033[91m \nHult is currently in attack of a virus \n\033[0m".format(name), 0.03)    
        t.sleep(0.05)
        type("\n\033[91m{}\033[0m you are a zombie hunter and you need to save the people inside Hult building\n".format(name),0.03)
        t.sleep(0.05)
        type("\n\033[91m{}\033[0m get ready to make some critical choices!!!\n".format(name),0.03)
        input(prompt="\n<Press ENTER/RETURN to continue...>\n")
        
        first_floor(name)

#first_floor entry to the building
        
def first_floor(in_name):
    zombie_1 = ["a","b","A","B","[a]","[A]","[b]","[B]"]
    for choice in zombie_1:
        
        type("\n\033[91m{}\033[0m Welcome to 1st floor\n\n".format(in_name) + "\U0001F9DF"*20 + "\n\nZombie\'s are approaching you... Wait what!!! you see \033[1mDean Chris\033[0m in danger\n\n\033[1mYou have 2 choices infornt of you\033[0m",0.03)        
        type("\n\033[94mA: Run to second floor and leave Dean Chris behind.\nB: Rescue Dean Chris from zobie attack but there is danger ahead.\033[0m",0.03) #random thought - not taken from anywhere
        choice = input(prompt="\nType\033[1m [A] \033[0mor\033[1m [B] \033[0mto make a selection - Be careful: ")  #input variable for selection
        
        if choice == "a" or choice == "A" or choice == "[a]" or choice == "[A]":
            t.sleep(0.5)
            type("\n\033[91m[{}] Opps, you got eaten by a zombie, try again\033[0m".format(choice) + "\U0001F915"*3 + "\n",0.03)
            fail(in_name)            
            
        elif choice == "b" or choice == "B" or choice == "[b]" or choice == "[B]":
            t.sleep(0.5)
            type("\n\033[92m[{}] Great choice you saved a life and killed a zombie.\n\nMove to the next stage\033[0m".format(choice) + "\U0001F60E"*3 + "\n",0.03)
            input("\n<Press ENTER/RETURN to conitnue>")
            break         #stop loop
        
        else:
            t.sleep(0.5)
            type("\n\033[95m[{}] invalid input, try again\033[0m\n".format(choice),0.03)
            fail(in_name)
            
            
    second_floor(in_name)
        
        
#second floor entry 

def second_floor(call_name):
    
        type("\n\033[91m{}\033[0m great Job! you have saved \033[1mDean Chris\033[0m \U0001F601 and successfully reached 2nd floor.\n\nPhew!!! no zombie\'s on 2nd floor...\n\nOh no! \033[1mThere is a security code to enter 3rd floor\033[0m".format(call_name), 0.03)
        type("\nwe are in Hult building security code can be opened only by python programe\n\n"+ "\U0001F4BB"*20 +"\n\n\033[1mChoose the correct syntax - You are thankful Prof. Chase tought you\033[0m", 0.03)
        zombie_2 = ["a","b","A","B","[a]","[A]","[b]","[B]"]
        
        for slct in zombie_2:
                type("\nIn which case zero \'0\' will NOT be printed\n\nlst = [1, 1, 1, 1, 0, 1, 1, 1, 1, 0, 1, 1, 1, 1, 1]",0.03)  #Taken from python class exercise - conditional statements - by Proffessor Chase Kusterer
                type("\n\033[94mA: for element in lst:\n\tprint(element)\n\tif element == 0:\n\t\tbreak\033[0m\n\033[95mB: for element in lst:\n\tif element == 0:\n\t\tbreak\n\tprint(element)\033[0m", 0.03)
                slct = input(prompt="\nType \033[1m[A]\033[0m or \033[1m[B]\033[0m to make a selection: \n")
                
                if slct == "a" or slct == "A" or slct == "[a]" or slct == "[A]":
                    t.sleep(0.5)
                    type("\n\033[91m[{}] Prof Chase won't be happy with you, TRY AGAIN\033[0m".format(slct) + "\U0001F620"*3 + "\n", 0.03)
                    fail_second_floor(call_name)
                    
                elif slct == "b" or slct == "B" or slct == "[b]" or slct == "[B]":
                    t.sleep(0.5)
                    type("\n\033[92m[{}] Good you remebered! Great job you move to the next stage\033[0m".format(slct) + "\U0001F60E"*3 +"\n", 0.03)
                    input("\n<Press ENTER/RETURN to continue>\n")
                    break
                    
                else:
                    t.sleep(0.5)
                    type("\n\033[95m[{}] invalid input, try again\033[0m\n".format(slct),0.03)
                    fail_second_floor(call_name)
        
        third_floor(call_name)
                  
        
#third floor entry

def third_floor(get_name):
    type("\n\033[91m{}\033[0m you are a true zombie hunter... well not so fast\n\nYou have reached last floor of the building\n\nOne more right decision and you will escape the building on a Helicopter\n\n".format(get_name),0.03)
    type("\U0001F681"*20,0.03)    #Helicopter emoji
    zombie_3 = ["a","A","[A]","[a]","b","B","[b]","[B]","c","C","[c]","[C]","february", "1989"]
    
    for puzzle in zombie_3:
        type("\n\n\033[1mYou have a puzzle infront of you.\033[0m\n\nDuring which month do people sleep the least?\n\033[94m[A] December\n[B] January\n[C] February\033[0m\n",0.03)  #Taken from Brain Den http://brainden.com/logic-riddles.htm -> STATISTICS
        puzzle = input(prompt= "\nType\033[1m [A] \033[0mor\033[1m [B] \033[0mor\033[1m [C] \033[0mto make a selection: \n")
        puzzle = puzzle.lower()
        if puzzle == "c" or puzzle == "C" or puzzle == "[c]" or puzzle == "[C]" or puzzle == "february":
            t.sleep(0.5)
            type("\n\033[92m [{}] Correct, As February has 28 days and in a leap year 29 days. Less nights than other months\n\nGreat job you move to the next puzzle\033[0m".format(puzzle),0.03)
            type("\n\nWhich month Tylor Swift was born? Hint: Same as Python\U0001F609\n[A] 1991\n[B] 1989\n[C] 1979",0.03) #Taken from Proffessor Chase Kusterer in class explanation
            
            for puzzle in zombie_3:
                puzzle = input(prompt= "Type \033[1m[A]\033[0m or \033[1m[B]\033[0m or \033[1m[C]\033[0m to make a selection: \n")  #input variable
                
                if puzzle == "b" or puzzle == "B" or puzzle == "[b]" or puzzle == "[B]" or puzzle == "1989":
                    t.sleep(0.5)
                    type("\n[{}] Hurray!!! you were finaly able to take the helicopter with Dean Chris\n\nYou are a true hero of Hult Zombie\n\nYou Win!!!".format(puzzle),0.03)
                    sys.exit("\nLucky day, enjoy!")               #stop
                    
                else:
                    t.sleep(0.5)
                    type("\n\033[95m[{}] Bad job, try again\033[0m\n".format(puzzle),0.03)
                    fail_third_floor(get_name)
        else:
            t.sleep(0.5)
            type("\n\033[95m[{}] oh no wrong answere, try again\033[0m\n".format(puzzle),0.03)
            fail_third_floor(get_name)
                        
    
#fail takes you back to first_floor or help you exit the game    

def fail(in_name):
    
    x = 3
    
    while x > 0:
        type("\nThe is not the correct answere\nYou have {} chances left\n[These chances are just for the options mentioned below]".format(x),0.03)
        x = x - 1
        
        play_again = input("\n\nWould you like to try again?\nEnter [Y]/[N] where Y represent as YES and N Represent as No:\n>")
        play_again = play_again.upper()
        
        if play_again == "Y" or play_again == "YES" or play_again == "Yes" or play_again == "yes":
            
            first_floor(in_name)
            break
        
        elif play_again == "N":
            input("\nThank you for playing the game.\nPress Enter to exit the game.\n>")            
            sys.exit("\nHave a good rest of your day\n")
            
        else:
            type("\nInvalid entry, try again\n",0.03)

#fail_second_floor takes you back to second_floor or help you exit the game

def fail_second_floor(call_name):
    
    x = 3
    
    while x > 0:
        type("\nThe is not the correct answere\nYou have {} chances left\n[These chances are just for the options mentioned below]".format(x),0.03)
        x = x - 1
        
        play_again = input("\n\nWould you like to try again?\nEnter [Y]/[N] where Y represent as YES and N Represent as No:\n>")
        play_again = play_again.upper()
        
        if play_again == "Y" or play_again == "YES" or play_again == "Yes" or play_again == "yes":
            
            second_floor(call_name)
            break
        
        elif play_again == "N":
            input("\nThank you for playing the game.\nPress Enter to exit the game.\n>")            
            sys.exit("\nHave a good rest of your day\n")
            
        else:
            type("\nInvalid entry, try again\n",0.03)
            
#fail_third_floor takes you back to third_floor or help you exit the game            

def fail_third_floor(get_name):
    
    x = 3
    
    while x > 0:
        type("\nThe is not the correct answere\n\nYou have {} chances left\n[These chances are just for the options mentioned below]".format(x),0.03)
        x = x - 1
        
        play_again = input("\n\nWould you like to try again?\nEnter [Y]/[N] where Y represent as YES and N Represent as No:\n>")
        play_again = play_again.upper()
        
        if play_again == "Y" or play_again == "YES" or play_again == "Yes" or play_again == "yes":
            
            third_floor(get_name)
            break
        
        elif play_again == "N":
            input("\nThank you for playing the game.\nPress Enter to exit the game.\n>")            
            sys.exit("\nHave a good rest of your day\n")
            
        else:
            type("\nInvalid entry, try again\n",0.03)
    
    
haunted_house()
# Out:
# ZOMBIE HULT!!!
#
# 🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟
#
# *********************************************
# *********************************************
# Fight for survival in a business school overrun by zombies! Can you stay alive long enough to get Hultians to a place of safety? If Yes...
# *********************************************
# *********************************************
#
# Enter your name to begin the game: stephan
#
# You are entring Hult building stephan 😃
#
# Hult is currently in attack of a virus
#
# stephan you are a zombie hunter and you need to save the people inside Hult building
#
# stephan get ready to make some critical choices!!!
#
# <Press ENTER/RETURN to continue...>
#
#
# stephan Welcome to 1st floor
#
# 🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟🧟
#
# Zombie's are approaching you... Wait what!!! you see Dean Chris in danger
#
# You have 2 choices infornt of you
# A: Run to second floor and leave Dean Chris behind.
# B: Rescue Dean Chris from zobie attack but there is danger ahead.
# ...
